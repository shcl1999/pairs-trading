# %% [markdown]
# # Imports

# %%
import yfinance as yf
from analysis import investigate_cointegration

# %%
# import Bitcoin and Ethereum data from Yahoo Finance
btc = yf.download('BTC-USD', start='2022-01-01', end='2023-01-01')
eth = yf.download('ETH-USD', start='2022-01-01', end='2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Look at Btc & Eth data

# %%
btc.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-01-01  46311.746094  47827.312500  46288.484375  47686.812500
# 2022-01-02  47680.925781  47881.406250  46856.937500  47345.218750
# 2022-01-03  47343.542969  47510.726562  45835.964844  46458.117188
# 2022-01-04  46458.851562  47406.546875  45752.464844  45897.574219
# 2022-01-05  45899.359375  46929.046875  42798.222656  43569.003906
#
#                Adj Close       Volume
# Date
# 2022-01-01  47686.812500  24582667004
# 2022-01-02  47345.218750  27951569547
# 2022-01-03  46458.117188  33071628362
# 2022-01-04  45897.574219  42494677905
# 2022-01-05  43569.003906  36851084859

# %%
eth.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-01  3683.047119  3769.917969  3682.286621  3769.697021  3769.697021
# 2022-01-02  3769.298340  3836.161865  3727.357422  3829.564941  3829.564941
# 2022-01-03  3829.535645  3836.198730  3698.047607  3761.380371  3761.380371
# 2022-01-04  3761.361572  3876.785156  3723.349854  3794.056641  3794.056641
# 2022-01-05  3794.269043  3842.059814  3456.745361  3550.386963  3550.386963
#
#                  Volume
# Date
# 2022-01-01   9776191466
# 2022-01-02   9881471548
# 2022-01-03  12080777893
# 2022-01-04  14030925983
# 2022-01-05  18061338502

# %%
#  plot the closing prices of Bitcoin and Ethereum
btc['Close'].plot()
eth['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Investigate cointegration BTH & ETH 2022-2023

# %%
investigate_cointegration(btc, eth, 1, 6000, 1)
# Out:
# P-VALUE: 0.08266910526386245   DF-STAT: -2.6522641969804357   CONSTANT: 2682.725781680279   SLOPE: 12.838440065343507   STRENGTH: 0.015312687000629897
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# /Users/sunny/Business/FutureEd/Tradingbot/Pairs Trading/cointegration_analysis.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alpha = short_run_ols_fit.params[0]
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# ...

# %% [markdown]
# # BTC and ETH in 2021-2022

# %%
# import Bitcoin and Ethereum data from Yahoo Finance
btc_2122 = yf.download('BTC-USD', start='2021-01-01', end='2022-01-01')
eth_2122 = yf.download('ETH-USD', start='2021-01-01', end='2022-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
investigate_cointegration(btc_2122, eth_2122, 1, 6000, 1)
# Out:
# P-VALUE: 0.46945477181507156   DF-STAT: -1.6262489370225697   CONSTANT: 32738.05708781725   SLOPE: 5.2904972314728695   STRENGTH: -0.012792408800889112
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# /Users/sunny/Business/FutureEd/Tradingbot/Pairs Trading/cointegration_analysis.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alpha = short_run_ols_fit.params[0]
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# ...

# %% [markdown]
# ### Seems like weak cointegration

# %% [markdown]
# # BTC and ETH in 2023

# %%
btc_23 = yf.download('BTC-USD', start='2023-01-01', end='2023-12-01')
eth_23 = yf.download('ETH-USD', start='2023-01-01', end='2023-12-01')

investigate_cointegration(btc_23, eth_23, 1, 6000, 1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# P-VALUE: 0.5918391103386225   DF-STAT: -1.3799722830410872   CONSTANT: -9313.997244083344   SLOPE: 21.06519877738027   STRENGTH: 0.02986666662485074
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# /Users/sunny/Business/FutureEd/Tradingbot/Pairs Trading/cointegration_analysis.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alpha = short_run_ols_fit.params[0]
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# ...

# %% [markdown]
# # 2022-2023 end

# %%
# BTC 2022-2023
btc_2223 = yf.download('BTC-USD', start='2022-01-01', end='2023-12-01')
eth_2223 = yf.download('ETH-USD', start='2022-01-01', end='2023-12-01')

investigate_cointegration(btc_2223, eth_2223, 1, 6000, 1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# P-VALUE: 0.4385962016045731   DF-STAT: -1.6855041943080689   CONSTANT: 3971.2088797647366   SLOPE: 12.766763498548576   STRENGTH: 0.017446312836115623
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# /Users/sunny/Business/FutureEd/Tradingbot/Pairs Trading/cointegration_analysis.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alpha = short_run_ols_fit.params[0]
# /Users/sunny/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:130: ValueWarning: unknown kwargs ['has_const']
#   warnings.warn(msg, ValueWarning)
# ...
